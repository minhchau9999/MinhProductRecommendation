# %% [markdown]
# # Bài 1: thực hiện tạo recommendation system dựa trên content-based

# %% [markdown]
# ## Functional Description
# - Build recommendation system using content-based
# - The system should recommend 10 most similar product names and description.
# - The system should prioritize to recommend products in the same subcategory first if the subcategory could be determined.
# - The system should prioritize to recommend products with higher rating.

# %% [markdown]
# ## Use cases
# - Use case 1: when user view a product, recommend 10 similar products.
# - Use case 2: when user search for a product, recommend 10 results that most match with key words.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity
from underthesea import word_tokenize, pos_tag, sent_tokenize
import warnings
from gensim import corpora, models, similarities
import re
import seaborn as sns

from utils import filter_vietnamese_words

# %%
# Load df from cleaned data

df = pd.read_pickle("./Products_ThoiTrangNam_cleaned.pkl")

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0         190              Áo ba lỗ thun gân ,form body tôn dáng
# 1         191  Áo Ba Lỗ Nam Trắng Chất Cotton Siêu Mát, Siêu Đẹp
# 2         192  Áo Ba Lỗ Nam Tyasuo chất vải co dãn mát, không...
# 3         193                 ÁO BA LỖ HÀNG VIỆT NAM 100% COTTON
# 4         194  Áo Thun Nam Thể Thao Ba Lỗ Mẫu Mới Siêu Đẹp (B...
#
#          category sub_category  \
# 0  Thời Trang Nam     Áo Ba Lỗ
# 1  Thời Trang Nam     Áo Ba Lỗ
# 2  Thời Trang Nam     Áo Ba Lỗ
# 3  Thời Trang Nam     Áo Ba Lỗ
# 4  Thời Trang Nam     Áo Ba Lỗ
#
#                                                 link  \
# 0  https://shopee.vn/%C3%81o-ba-l%E1%BB%97-thun-g...
# 1  https://shopee.vn/%C3%81o-Ba-L%E1%BB%97-Nam-Tr...
# 2  https://shopee.vn/%C3%81o-Ba-L%E1%BB%97-Nam-Ty...
# 3  https://shopee.vn/%C3%81O-BA-L%E1%BB%96-H%C3%8...
# 4  https://shopee.vn/%C3%81o-Thun-Nam-Th%E1%BB%83...
#
#                                                image    price  rating  \
# 0  https://cf.shopee.vn/file/2c1ca03f5dc42f316fdf...  86250.0     4.9
# 1  https://cf.shopee.vn/file/c7ea4c6574dc79be6b26...  26800.0     4.9
# 2  https://cf.shopee.vn/file/6f93bcda10efe374f8cc...  39500.0     4.8
# 3  https://cf.shopee.vn/file/1d7ed5e34bff8bc8b49a...  16500.0     4.8
# 4                                                NaN  45000.0     4.8
#
#                                          description
# 0     Áo Ba Lỗ Chiều dài tay áo Khác Phong cách T...
# 1     Áo Ba Lỗ Xuất xứ Việt Nam Tên tổ chức chịu ...
# 2     Áo Ba Lỗ Thương hiệu Tyasuo Chiều dài tay á...
# 3     Áo Ba Lỗ Chất liệu Cotton Kho hàng 7981 Gửi...
# 4     Áo Ba Lỗ Chiều dài tay áo Không tay Phong c...

# %%
STOP_WORD_FILE = './vietnamese-stopwords.txt'
with open(STOP_WORD_FILE, 'r', encoding='utf-8') as file:
    stop_words = file.read()

stop_words = stop_words.split('\n')

# %%
# filter Vietnamese words
df['description_clean'] = df['description'].apply(filter_vietnamese_words)

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0         190              Áo ba lỗ thun gân ,form body tôn dáng
# 1         191  Áo Ba Lỗ Nam Trắng Chất Cotton Siêu Mát, Siêu Đẹp
# 2         192  Áo Ba Lỗ Nam Tyasuo chất vải co dãn mát, không...
# 3         193                 ÁO BA LỖ HÀNG VIỆT NAM 100% COTTON
# 4         194  Áo Thun Nam Thể Thao Ba Lỗ Mẫu Mới Siêu Đẹp (B...
#
#          category sub_category  \
# 0  Thời Trang Nam     Áo Ba Lỗ
# 1  Thời Trang Nam     Áo Ba Lỗ
# 2  Thời Trang Nam     Áo Ba Lỗ
# 3  Thời Trang Nam     Áo Ba Lỗ
# 4  Thời Trang Nam     Áo Ba Lỗ
#
#                                                 link  \
# 0  https://shopee.vn/%C3%81o-ba-l%E1%BB%97-thun-g...
# 1  https://shopee.vn/%C3%81o-Ba-L%E1%BB%97-Nam-Tr...
# 2  https://shopee.vn/%C3%81o-Ba-L%E1%BB%97-Nam-Ty...
# 3  https://shopee.vn/%C3%81O-BA-L%E1%BB%96-H%C3%8...
# 4  https://shopee.vn/%C3%81o-Thun-Nam-Th%E1%BB%83...
#
#                                                image    price  rating  \
# 0  https://cf.shopee.vn/file/2c1ca03f5dc42f316fdf...  86250.0     4.9
# 1  https://cf.shopee.vn/file/c7ea4c6574dc79be6b26...  26800.0     4.9
# 2  https://cf.shopee.vn/file/6f93bcda10efe374f8cc...  39500.0     4.8
# 3  https://cf.shopee.vn/file/1d7ed5e34bff8bc8b49a...  16500.0     4.8
# 4                                                NaN  45000.0     4.8
#
#                                          description  \
# 0     Áo Ba Lỗ Chiều dài tay áo Khác Phong cách T...
# 1     Áo Ba Lỗ Xuất xứ Việt Nam Tên tổ chức chịu ...
# 2     Áo Ba Lỗ Thương hiệu Tyasuo Chiều dài tay á...
# 3     Áo Ba Lỗ Chất liệu Cotton Kho hàng 7981 Gửi...
# 4     Áo Ba Lỗ Chiều dài tay áo Không tay Phong c...
#
#                                    description_clean
# 0  Áo Ba Lỗ Chiều dài tay áo Khác Phong cách Thể ...
# 1  Áo Ba Lỗ Xuất xứ Việt Nam Tên tổ chức chịu trá...
# 2  Áo Ba Lỗ Thương hiệu Tyasuo Chiều dài tay áo K...
# 3  Áo Ba Lỗ Chất liệu Cotton Kho hàng 7981 Gửi từ...
# 4  Áo Ba Lỗ Chiều dài tay áo Không tay Phong cách...

# %%
# create the content
# as we keept the subcategories in the description, let only use product name and description to create the content

df['Content'] = df['product_name'] + ' ' + df['description_clean'].apply(lambda x: ' '.join(x.split()[:200]))

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0         190              Áo ba lỗ thun gân ,form body tôn dáng
# 1         191  Áo Ba Lỗ Nam Trắng Chất Cotton Siêu Mát, Siêu Đẹp
# 2         192  Áo Ba Lỗ Nam Tyasuo chất vải co dãn mát, không...
# 3         193                 ÁO BA LỖ HÀNG VIỆT NAM 100% COTTON
# 4         194  Áo Thun Nam Thể Thao Ba Lỗ Mẫu Mới Siêu Đẹp (B...
#
#          category sub_category  \
# 0  Thời Trang Nam     Áo Ba Lỗ
# 1  Thời Trang Nam     Áo Ba Lỗ
# 2  Thời Trang Nam     Áo Ba Lỗ
# 3  Thời Trang Nam     Áo Ba Lỗ
# 4  Thời Trang Nam     Áo Ba Lỗ
#
#                                                 link  \
# 0  https://shopee.vn/%C3%81o-ba-l%E1%BB%97-thun-g...
# 1  https://shopee.vn/%C3%81o-Ba-L%E1%BB%97-Nam-Tr...
# 2  https://shopee.vn/%C3%81o-Ba-L%E1%BB%97-Nam-Ty...
# 3  https://shopee.vn/%C3%81O-BA-L%E1%BB%96-H%C3%8...
# 4  https://shopee.vn/%C3%81o-Thun-Nam-Th%E1%BB%83...
#
#                                                image    price  rating  \
# 0  https://cf.shopee.vn/file/2c1ca03f5dc42f316fdf...  86250.0     4.9
# 1  https://cf.shopee.vn/file/c7ea4c6574dc79be6b26...  26800.0     4.9
# 2  https://cf.shopee.vn/file/6f93bcda10efe374f8cc...  39500.0     4.8
# 3  https://cf.shopee.vn/file/1d7ed5e34bff8bc8b49a...  16500.0     4.8
# 4                                                NaN  45000.0     4.8
#
#                                          description  \
# 0     Áo Ba Lỗ Chiều dài tay áo Khác Phong cách T...
# 1     Áo Ba Lỗ Xuất xứ Việt Nam Tên tổ chức chịu ...
# 2     Áo Ba Lỗ Thương hiệu Tyasuo Chiều dài tay á...
# 3     Áo Ba Lỗ Chất liệu Cotton Kho hàng 7981 Gửi...
# 4     Áo Ba Lỗ Chiều dài tay áo Không tay Phong c...
#
#                                    description_clean  \
# 0  Áo Ba Lỗ Chiều dài tay áo Khác Phong cách Thể ...
# 1  Áo Ba Lỗ Xuất xứ Việt Nam Tên tổ chức chịu trá...
# 2  Áo Ba Lỗ Thương hiệu Tyasuo Chiều dài tay áo K...
# 3  Áo Ba Lỗ Chất liệu Cotton Kho hàng 7981 Gửi từ...
# 4  Áo Ba Lỗ Chiều dài tay áo Không tay Phong cách...
#
#                                              Content
# 0  Áo ba lỗ thun gân ,form body tôn dáng Áo Ba Lỗ...
# 1  Áo Ba Lỗ Nam Trắng Chất Cotton Siêu Mát, Siêu ...
# 2  Áo Ba Lỗ Nam Tyasuo chất vải co dãn mát, không...
# 3  ÁO BA LỖ HÀNG VIỆT NAM 100% COTTON Áo Ba Lỗ Ch...
# 4  Áo Thun Nam Thể Thao Ba Lỗ Mẫu Mới Siêu Đẹp (B...

# %%
#!pip install pandarallel
from pandarallel import pandarallel

# %%
# word_tokenize
# use to split sentences into words, combined words returned as word1_word2
# Example: >>> sentence = "Bác sĩ bây giờ có thể thản nhiên báo tin bệnh nhân bị ung thư"
        # >>> word_tokenize(sentence)
        # ["Bác sĩ", "bây giờ", "có thể", "thản nhiên", "báo tin", "bệnh nhân", "bị", "ung thư"]
pandarallel.initialize(progress_bar=True, nb_workers=4)



# df["Content_wt"]=df["Content"].apply(lambda x: word_tokenize(x, format="text"))
# Out:
# INFO: Pandarallel will run on 4 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.
#
# WARNING: You are on Windows. If you detect any issue with pandarallel, be sure you checked out the Troubleshooting page:
# https://nalepae.github.io/pandarallel/troubleshooting/

# %%
def tokenize_text(text):
    from underthesea import word_tokenize
    return word_tokenize(text, format="text")

df["Content_wt"] = df["Content"].parallel_apply(tokenize_text)
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=11707), Label(value='0 / 11707')))…

# %%
df[["Content", "Content_wt"]].head()
# Out:
#                                              Content  \
# 0  Áo ba lỗ thun gân ,form body tôn dáng Áo Ba Lỗ...
# 1  Áo Ba Lỗ Nam Trắng Chất Cotton Siêu Mát, Siêu ...
# 2  Áo Ba Lỗ Nam Tyasuo chất vải co dãn mát, không...
# 3  ÁO BA LỖ HÀNG VIỆT NAM 100% COTTON Áo Ba Lỗ Ch...
# 4  Áo Thun Nam Thể Thao Ba Lỗ Mẫu Mới Siêu Đẹp (B...
#
#                                           Content_wt
# 0  Áo ba lỗ thun gân , form body tôn_dáng Áo_Ba_L...
# 1  Áo Ba_Lỗ Nam_Trắng Chất_Cotton Siêu_Mát , Siêu...
# 2  Áo Ba_Lỗ Nam_Tyasuo chất vải co_dãn mát , khôn...
# 3  ÁO BA_LỖ HÀNG_VIỆT_NAM 100 % COTTON_Áo Ba_Lỗ C...
# 4  Áo Thun_Nam Thể_Thao Ba_Lỗ Mẫu_Mới Siêu_Đẹp ( ...

# %%
# remove stop words
# df["Content_wt"]=df["Content_wt"].apply(lambda x: ' '.join([word for word in x.split() if not word in stop_words]))

def remove_stopwords(text, stops=stop_words):
    """Function that passes stop_words as a parameter to avoid the NameError"""
    return ' '.join([word for word in text.split() if word not in stops])

#also use parallel
# this way need to define the func remove_stopwords becasue the stop_words variable above is not
#... automatically available in the worker processes
df["Content_wt"]=df["Content_wt"].parallel_apply(remove_stopwords)
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=11707), Label(value='0 / 11707')))…

# %%
# maybe dump into a pickle file so that no need to re-run in case of crash.

df.to_pickle('./df_content_wt.pkl')

# %%
# load pkl file if needed

# df = pd.read_pickle('./df_content_wt.pkl')

# %% [markdown]
# ## Using Gensim

# %%
# Tokenize(split) the sentences into words
content_Gensim = [[text for text in x.split()] for x in df.Content_wt]

# %%
len(content_Gensim)
# Out:
# 46828

# %%
content_Gensim[:1]
# Out:
# [['Áo',
#   'lỗ',
#   'thun',
#   'gân',
#   ',',
#   'form',
#   'body',
#   'tôn_dáng',
#   'Áo_Ba_Lỗ',
#   'Chiều',
#   'tay_áo',
#   'Khác',
#   'Phong_cách',
#   'Thể_Cơ_bản',
#   ',',
#   'Đường_phố',
#   ',',
#   'Nhiệt_đới',
#   'Tall_Fit',
#   'Có',
#   'Xuất_xứ',
#   'Việt_Nam_Dáng',
#   'kiểu',
#   'áo',
#   'Ôm_sát',
#   'Chất_liệu',
#   'Cotton_Mẫu',
#   'Sọc_tăm',
#   'gân',
#   'nổi',
#   'Kho',
#   'hàng',
#   '75317',
#   'Gửi',
#   'Bà_Rịa',
#   'Vũng_Tàu',
#   'BEST',
#   'TANK_TOPS',
#   'FOR_MEN',
#   '2021',
#   'Áo_Ba',
#   'Lỗ_Quốc_Dân',
#   'Cho_Nam',
#   'Bảng_size',
#   'Size_M',
#   'Size_L',
#   '55',
#   'kg',
#   'Size_XL',
#   '70',
#   'kg',
#   'Size_XXL',
#   '75',
#   'kg',
#   '80',
#   'kg',
#   '(',
#   'Bảng_size',
#   'chuẩn',
#   'mặc',
#   'kiểu',
#   'body_nha',
#   'quý_khách',
#   'không',
#   'thích',
#   'mặc',
#   'ôm',
#   '1',
#   'size',
#   'mặc',
#   'rộng',
#   'rộng',
#   '2',
#   'size',
#   'bảng',
#   'size',
#   'tính_chất',
#   'tham_khảo',
#   'khách_thể',
#   'hình',
#   'không',
#   'cân_đối',
#   '.',
#   'Để',
#   'tư_vấn',
#   'chính_xác',
#   'vui_lòng',
#   'inbox',
#   'shop',
#   ')',
#   'Kích_thước',
#   'Size',
#   '66',
#   'cm',
#   'Rộng',
#   '(',
#   'vòng',
#   'ngực',
#   'Size',
#   'Rộng',
#   '43',
#   'cm',
#   '(',
#   'vòng',
#   'ngực',
#   'Size_XL',
#   ':',
#   '70',
#   'cm',
#   'Rộng',
#   '47',
#   'cm',
#   '(',
#   'vòng',
#   'ngực',
#   'Size',
#   '72',
#   'cm',
#   'Rộng',
#   '51',
#   'cm',
#   '(',
#   'vòng',
#   'ngực',
#   'Vòng',
#   'nách',
#   'M',
#   '25',
#   'cm',
#   'L',
#   '27',
#   'cm',
#   '29',
#   'cm',
#   'XXL',
#   '31',
#   'cm',
#   'Bảng_size',
#   'mặc',
#   'cơ_thể',
#   '(',
#   'không',
#   'ôm',
#   'sát',
#   'không',
#   'rộng',
#   ')']]

# %%
# data preprocessing for gensim
from utils import data_preprocessing_for_gensim

content_Gensim_processed = data_preprocessing_for_gensim(text=content_Gensim,remove_number=True, remove_special_chars= True, stop_words=stop_words)

# %%
content_Gensim_processed[:1]
# Out:
# [['áo',
#   'lỗ',
#   'thun',
#   'gân',
#   'form',
#   'body',
#   'tôn_dáng',
#   'áo_ba_lỗ',
#   'chiều',
#   'tay_áo',
#   'phong_cách',
#   'thể_cơ_bản',
#   'đường_phố',
#   'nhiệt_đới',
#   'tall_fit',
#   'xuất_xứ',
#   'việt_nam_dáng',
#   'kiểu',
#   'áo',
#   'ôm_sát',
#   'chất_liệu',
#   'cotton_mẫu',
#   'sọc_tăm',
#   'gân',
#   'nổi',
#   'kho',
#   'hàng',
#   'gửi',
#   'bà_rịa',
#   'vũng_tàu',
#   'best',
#   'tank_tops',
#   'for_men',
#   'áo_ba',
#   'lỗ_quốc_dân',
#   'cho_nam',
#   'bảng_size',
#   'size_m',
#   'size_l',
#   'kg',
#   'size_xl',
#   'kg',
#   'size_xxl',
#   'kg',
#   'kg',
#   'bảng_size',
#   'chuẩn',
#   'mặc',
#   'kiểu',
#   'body_nha',
#   'quý_khách',
#   'không',
#   'thích',
#   'mặc',
#   'ôm',
#   'size',
#   'mặc',
#   'rộng',
#   'rộng',
#   'size',
#   'bảng',
#   'size',
#   'tính_chất',
#   'tham_khảo',
#   'khách_thể',
#   'hình',
#   'không',
#   'cân_đối',
#   'tư_vấn',
#   'chính_xác',
#   'vui_lòng',
#   'inbox',
#   'shop',
#   'kích_thước',
#   'size',
#   'cm',
#   'rộng',
#   'vòng',
#   'ngực',
#   'size',
#   'rộng',
#   'cm',
#   'vòng',
#   'ngực',
#   'size_xl',
#   'cm',
#   'rộng',
#   'cm',
#   'vòng',
#   'ngực',
#   'size',
#   'cm',
#   'rộng',
#   'cm',
#   'vòng',
#   'ngực',
#   'vòng',
#   'nách',
#   'm',
#   'cm',
#   'l',
#   'cm',
#   'cm',
#   'xxl',
#   'cm',
#   'bảng_size',
#   'mặc',
#   'cơ_thể',
#   'không',
#   'ôm',
#   'sát',
#   'không',
#   'rộng']]

# %%
# Add the processed content to the DataFrame
df['content_processed'] = content_Gensim_processed

# %%
# Obtain the number of features based on dictionary: Use corpora.Dictionary
dictionary = corpora.Dictionary(df['content_processed'] )

# %%
print(dictionary)
# Out:
# Dictionary<144190 unique tokens: ['best', 'body', 'body_nha', 'bà_rịa', 'bảng']...>

# %%
# List of features in dictionary
dictionary.token2id
# Out:
# {'best': 0,
#  'body': 1,
#  'body_nha': 2,
#  'bà_rịa': 3,
#  'bảng': 4,
#  'bảng_size': 5,
#  'chiều': 6,
#  'cho_nam': 7,
#  'chuẩn': 8,
#  'chính_xác': 9,
#  'chất_liệu': 10,
#  'cm': 11,
#  'cotton_mẫu': 12,
#  'cân_đối': 13,
#  'cơ_thể': 14,
#  'for_men': 15,
#  'form': 16,
#  'gân': 17,
#  'gửi': 18,
#  'hàng': 19,
#  'hình': 20,
#  'inbox': 21,
#  'kg': 22,
#  'kho': 23,
#  'khách_thể': 24,
#  'không': 25,
#  'kiểu': 26,
#  'kích_thước': 27,
#  'l': 28,
#  'lỗ': 29,
#  'lỗ_quốc_dân': 30,
#  'm': 31,
#  'mặc': 32,
#  'ngực': 33,
#  'nhiệt_đới': 34,
#  'nách': 35,
#  'nổi': 36,
#  'phong_cách': 37,
#  'quý_khách': 38,
#  'rộng': 39,
#  'shop': 40,
#  'size': 41,
#  'size_l': 42,
#  'size_m': 43,
#  'size_xl': 44,
#  'size_xxl': 45,
#  'sát': 46,
#  'sọc_tăm': 47,
#  'tall_fit': 48,
#  'tank_tops': 49,
#  'tay_áo': 50,
#  'tham_khảo': 51,
#  'thun': 52,
#  'thích': 53,
#  'thể_cơ_bản': 54,
#  'tính_chất': 55,
#  'tôn_dáng': 56,
#  'tư_vấn': 57,
#  'việt_nam_dáng': 58,
#  'vui_lòng': 59,
#  'vòng': 60,
#  'vũng_tàu': 61,
#  'xuất_xứ': 62,
#  'xxl': 63,
#  'áo': 64,
#  'áo_ba': 65,
#  'áo_ba_lỗ': 66,
#  'ôm': 67,
#  'ôm_sát': 68,
#  'đường_phố': 69,
#  'an_toàn': 70,
#  'aobalo': 71,
#  'aolo': 72,
#  'aolot': 73,
#  'aonot': 74,
#  'aophongbalo': 75,
#  'aothun': 76,
#  'aothuncotron': 77,
#  'aothundep': 78,
#  'aothundongphucaothuntron': 79,
#  'aothunhanquoc': 80,
#  'aothunin': 81,
#  'aothunnam': 82,
#  'aothunnamdep': 83,
#  'aothuntrang': 84,
#  'azman_địa_chỉ': 85,
#  'ba_lỗ': 86,
#  'chất_cotton': 87,
#  'co_giãn': 88,
#  'cotton': 89,
#  'giúp': 90,
#  'hà_nội': 91,
#  'hà_đông': 92,
#  'hôi': 93,
#  'hút': 94,
#  'hại': 95,
#  'khoắn': 96,
#  'khó_chịu': 97,
#  'khỏe': 98,
#  'lằn': 99,
#  'mái': 100,
#  'mềm_mại': 101,
#  'mổ': 102,
#  'nam_giới': 103,
#  'nam_trắng': 104,
#  'năng_động': 105,
#  'phú_lãm': 106,
#  'siêu_mát': 107,
#  'siêu_đẹp': 108,
#  'sản_phẩm': 109,
#  'sản_xuất': 110,
#  'sức': 111,
#  'thiết_kế': 112,
#  'thoáng_khí': 113,
#  'thấm': 114,
#  'thỏa': 115,
#  'trách_nhiệm': 116,
#  'tốt': 117,
#  'tổ_chức': 118,
#  'việt': 119,
#  'việt_nam': 120,
#  'vải': 121,
#  'vết': 122,
#  'đem': 123,
#  'đơn_giản': 124,
#  '"': 125,
#  'big_size': 126,
#  'chênh_lệch': 127,
#  'chút': 128,
#  'chất': 129,
#  'chất_lượng': 130,
#  'co_dãn': 131,
#  'cải_thiện': 132,
#  'cổ_viền': 133,
#  'giá': 134,
#  'giá_thành': 135,
#  'góp_ý': 136,
#  'hầu_như': 137,
#  'hồ_chí_minh': 138,
#  'hồ_chí_minh_update': 139,
#  'khách_hàng': 140,
#  'kết_luận': 141,
#  'lưu_ý': 142,
#  'màu_sắc': 143,
#  'mát': 144,
#  'mô_tả': 145,
#  'mẫu_trơn': 146,
#  'mắt': 147,
#  'mặc_mát': 148,
#  'mặt_mát': 149,
#  'mềm': 150,
#  'mềm_mịn': 151,
#  'mịn_áo': 152,
#  'nam_tyasuo': 153,
#  'ngang': 154,
#  'nhão': 155,
#  'nhăn': 156,
#  'pha': 157,
#  'phân_khúc': 158,
#  'polyester': 159,
#  'rẻ': 160,
#  'spandex': 161,
#  'thoải_mái': 162,
#  'thun_cotton': 163,
#  'thun_tc': 164,
#  'thành_phần': 165,
#  'thương_hiệu': 166,
#  'thủ_đức': 167,
#  'thức_tế': 168,
#  'tp.': 169,
#  'trường': 170,
#  'tyasuo': 171,
#  'tyasuo_shop': 172,
#  'xù': 173,
#  'đặc_tính': 174,
#  'đặt_biệt': 175,
#  'địa_chỉ': 176,
#  'độ': 177,
#  'ảnh': 178,
#  '-----------------------_hàng': 179,
#  '--------------------_áo': 180,
#  'ba_lỗ_nam': 181,
#  'cao_cấp': 182,
#  'chatcotton': 183,
#  'cotton_áo': 184,
#  'cảm_giác': 185,
#  'giáng': 186,
#  'hàng_việt_nam': 187,
#  'khô': 188,
#  'khả_năng': 189,
#  'kích_ứng_áo': 190,
#  'mặc_lót': 191,
#  'mặt': 192,
#  'mịn': 193,
#  'quy_trình': 194,
#  'sơ_mi': 195,
#  'thoát': 196,
#  'thấm_hút': 197,
#  'tự_tin': 198,
#  'xl_xxl': 199,
#  'đi_thể': 200,
#  'đại_đa_số': 201,
#  'độc_hại': 202,
#  'bl': 203,
#  'cam_kết': 204,
#  'cực_kì': 205,
#  'ghi_chú': 206,
#  'giao': 207,
#  'giải_quyết': 208,
#  'hàng_trước': 209,
#  'hệ_thống': 210,
#  'kgkg': 211,
#  'kim': 212,
#  'kiểu_dáng': 213,
#  'ko': 214,
#  'lao_hà': 215,
#  'lỗi': 216,
#  'men': 217,
#  'miễn_phí': 218,
#  'màu': 219,
#  'mẫu_mới': 220,
#  'mồ_hôi': 221,
#  'mỗ': 222,
#  'nhanh_chóng': 223,
#  'nhầm': 224,
#  'quảng_cáo': 225,
#  'ship_cod': 226,
#  'slimfit': 227,
#  'thanh_bình': 228,
#  'thoáng_mát': 229,
#  'thun_nam': 230,
#  'thông_tin': 231,
#  'thương_hiệuthe': 232,
#  'thể_thao': 233,
#  'toàn_quốc_nhận': 234,
#  'trường_hợp': 235,
#  'trả_tiền': 236,
#  'xl': 237,
#  'xuất_nhập_khẩu': 238,
#  'áo_ba_lỗ_nam': 239,
#  'áo_ba_lỗ_tập_gym': 240,
#  'áo_gym': 241,
#  'áo_thun': 242,
#  'áo_thun_tập_gym': 243,
#  'áo_tập_gym': 244,
#  'đông': 245,
#  'đổi': 246,
#  '!': 247,
#  'ao': 248,
#  'aothethao': 249,
#  'bodonam': 250,
#  'bothethao': 251,
#  'chuân': 252,
#  'công_ty': 253,
#  'dễ_dàng_phối': 254,
#  'form_chuẩn': 255,
#  'hè': 256,
#  'kem': 257,
#  'kim_hoài_đức': 258,
#  'kê': 259,
#  'kêt_hơp': 260,
#  'l_xl': 261,
#  'lai_xá': 262,
#  'may_kĩ': 263,
#  'mát_áo': 264,
#  'mô': 265,
#  'mùa': 266,
#  'măc': 267,
#  'mạnh_mẽ': 268,
#  'mẫu': 269,
#  'nam': 270,
#  'phân': 271,
#  'phố': 272,
#  'quanthethao': 273,
#  'quân': 274,
#  'sát_nách': 275,
#  'săc': 276,
#  'sư': 277,
#  'sắc_sảo': 278,
#  'tanktop': 279,
#  'tao_sư': 280,
#  'thich_hơp': 281,
#  'thiêt': 282,
#  'thoai_mai': 283,
#  'thoitrangnam': 284,
#  'thâm_hut': 285,
#  'thích_hợp': 286,
#  'thời_trang': 287,
#  'tinh_tế': 288,
#  'tiện_lợi': 289,
#  'trang_phục': 290,
#  'tre': 291,
#  'trung_năng': 292,
#  'tốt_thoáng': 293,
#  'vai': 294,
#  'vinagreentech_địa_chỉ': 295,
#  'vê': 296,
#  'wolmaxx': 297,
#  'xnk': 298,
#  'xu_hướng': 299,
#  'đa_phong_cách': 300,
#  'đep': 301,
#  'đi_dạo': 302,
#  'đươc': 303,
#  'đương_may': 304,
#  'đường': 305,
#  'đường_may': 306,
#  'đầu_tư': 307,
#  'bối_cảnh': 308,
#  'cam_kết_bạn': 309,
#  'chi_tiết': 310,
#  'co': 311,
#  'cá_tính': 312,
#  'cơ_bắp': 313,
#  'freeship_extra': 314,
#  'giãn_mã': 315,
#  'gym': 316,
#  'hiện_đại': 317,
#  'hoàn': 318,
#  'huyện_thanh': 319,
#  'họa_tiết': 320,
#  'k': 321,
#  'kiểu_dáng_thể': 322,
#  'lót_form': 323,
#  'may_kỹ': 324,
#  'mẫu_in': 325,
#  'mịn_tập': 326,
#  'ngắn': 327,
#  'nhà_sản_xuất': 328,
#  'sang_trọng': 329,
#  'tank_top': 330,
#  'thun_trơn': 331,
#  'thời': 332,
#  'trang_nhã': 333,
#  'trung_năng_động': 334,
#  'trẻ': 335,
#  'tt_là': 336,
#  'tặng': 337,
#  'tỉ_mỉ': 338,
#  'unifun_áo': 339,
#  'đơn': 340,
#  'đơn_từ': 341,
#  'đặc_điểm': 342,
#  'bl_áo': 343,
#  'gym_nam_shark': 344,
#  'hàng_đẹp': 345,
#  'hướng_dẫn': 346,
#  'lỗ_thể_nam': 347,
#  'nam_shark': 348,
#  'thoáng': 349,
#  'thun_tập': 350,
#  'thể_nam': 351,
#  'thể_thao_dáng': 352,
#  'tốt_xl': 353,
#  'áo_slim': 354,
#  '!_tên': 355,
#  '[': 356,
#  '[_al': 357,
#  ']_áo': 358,
#  'chụp': 359,
#  'coton': 360,
#  'cotton_mỏng': 361,
#  'có_mặt': 362,
#  'dáng_suông': 363,
#  'gây_gổ': 364,
#  'hanoi_vietnam': 365,
#  'hàng_do': 366,
#  'kiểm_tra': 367,
#  'lỗ_may': 368,
#  'may': 369,
#  'mã_skamonth': 370,
#  'mẫu_mã': 371,
#  'mặc_nhà': 372,
#  'mỏng_mát': 373,
#  'number': 374,
#  'phái': 375,
#  'phù': 376,
#  'quần_may': 377,
#  'shop_tự': 378,
#  'thiết_thực': 379,
#  'thị_trường': 380,
#  'trắng': 381,
#  'tuyển_lựa': 382,
#  'tâp_thể': 383,
#  'áo_lót': 384,
#  'áo_ngủ': 385,
#  'áo_sơ': 386,
#  'ích_lợi': 387,
#  'ô_number': 388,
#  'ô_vải': 389,
#  'đơn_k': 390,
#  'đơn_thuần': 391,
#  'đổi_trả': 392,
#  'ưu_điểm': 393,
#  'bảo_vệ': 394,
#  'bền_màu': 395,
#  'chơi_thể': 396,
#  'cân': 397,
#  'cộc_tay': 398,
#  'dễ_dàng': 399,
#  'dệt': 400,
#  'giặt': 401,
#  'hoạt_động': 402,
#  'khử_khuẩn': 403,
#  'kết_hợp': 404,
#  'liên_hệ': 405,
#  'lót_nam': 406,
#  'màu_trắng': 407,
#  'nghỉ_mát': 408,
#  'nhật_maxtino': 409,
#  'phông_nam_cotton': 410,
#  'sạch': 411,
#  'vải_cotton': 412,
#  'vận_động': 413,
#  'xuân': 414,
#  'xuất_khẩu': 415,
#  'xuất_nhật_maxtino': 416,
#  'áo_phông': 417,
#  'áobalonam': 418,
#  'áobalỗchonam': 419,
#  'áobalỗnam': 420,
#  'áocộctaynam': 421,
#  'áolótlỗnam': 422,
#  'áolótnam': 423,
#  'áolótnammặckèmsơmi': 424,
#  'áolótnamtrắng': 425,
#  'áolỗ': 426,
#  'áolỗnamtậpgym': 427,
#  'áolỗnamđẹp': 428,
#  'áomặcnhànam': 429,
#  'áođôngxuânnam': 430,
#  'đông_xuân_cộc': 431,
#  'đông_xuân_xuất': 432,
#  'ảnh_hưởng': 433,
#  'ac': 434,
#  'ac_áo': 435,
#  'aristino': 436,
#  'aristino_mã_sản_phẩm': 437,
#  'aristino_thun': 438,
#  'chú_trọng': 439,
#  'classic_chất': 440,
#  'cuốn_hút': 441,
#  'cổ_phần': 442,
#  'form_dáng': 443,
#  'hcm': 444,
#  'hàn_quốc': 445,
#  'kg_việt_nam': 446,
#  'lịch_lãm': 447,
#  'lỗ_lót': 448,
#  'lỗ_nam': 449,
#  'lựa_chọn': 450,
#  'mặt_hàng': 451,
#  'mịn_ac': 452,
#  'nam_cao_cấp': 453,
#  'nguyễn_trãi': 454,
#  'phường': 455,
#  'tp': 456,
#  'trơn': 457,
#  'trắng_trơn': 458,
#  'tây_hồ': 459,
#  'tự_nhiên': 460,
#  'yêu_thích': 461,
#  'áo_rộng': 462,
#  'đa_dạng': 463,
#  'đơn_giản_dáng': 464,
#  'bám': 465,
#  'bảo_quản': 466,
#  'bấm': 467,
#  'bụng': 468,
#  'cao_cao_cao_cao_cao_bạn': 469,
#  'dài_chất': 470,
#  'dính': 471,
#  'giá_cả': 472,
#  'giỏ': 473,
#  'gugostar_g': 474,
#  'hướng_dẫn_cách': 475,
#  'hết_sức': 476,
#  'hợp_lý': 477,
#  'mua': 478,
#  'mè_lạnh': 479,
#  'nam_tay': 480,
#  'nam_tính': 481,
#  'nút': 482,
#  'quần_quần': 483,
#  'tay_áo_dài': 484,
#  'thanh_toán': 485,
#  'thun_lạnh': 486,
#  'tiến_hành': 487,
#  'to': 488,
#  'đôn_lên': 489,
#  'đầu': 490,
#  'đầy_đủ': 491,
#  'đặt_hàng': 492,
#  'ấn': 493,
#  'chào_các': 494,
#  'chăm_sóc': 495,
#  'dập_vân': 496,
#  'ghé': 497,
#  'giới_thiệu': 498,
#  'hiệp_thuận': 499,
#  'hài_lòng': 500,
#  'hân_hạnh_được': 501,
#  'lạnh': 502,
#  'nách_chất': 503,
#  'phom': 504,
#  'phom_-': 505,
#  'phúc_thọ': 506,
#  'phục_vụ': 507,
#  'shop_huychisport': 508,
#  'shop_tiến_sport': 509,
#  'sẵn': 510,
#  'sẵn_sàng_nhận': 511,
#  'thăm': 512,
#  'thể_thao_nam': 513,
#  'tiền': 514,
#  'tùy': 515,
#  'xả_lỗ': 516,
#  'áo_sát': 517,
#  'att': 518,
#  'cam_kết_của': 519,
#  'cotton_s': 520,
#  'cơ_bản': 521,
#  'dáng_thể': 522,
#  'ghi': 523,
#  'hàng_nếu': 524,
#  'hơi': 525,
#  'khỏe_khoắn': 526,
#  'lê_lợi': 527,
#  'lỗi_do': 528,
#  'người_việt': 529,
#  'người_yêu': 530,
#  'nách_nam': 531,
#  'nổi_bật': 532,
#  'phom_dáng': 533,
#  's': 534,
#  's_m': 535,
#  's_màu': 536,
#  'sado_địa_chỉ': 537,
#  'size_chuẩn': 538,
#  'slim_fit': 539,
#  'số_đo': 540,
#  'thành_phố': 541,
#  'tím_đen': 542,
#  'tính_năng': 543,
#  'xanh': 544,
#  'ôm_dáng': 545,
#  'đá': 546,
#  'đề_thám': 547,
#  'ba_lổ': 548,
#  'chọn_lựa': 549,
#  'cotton_mát': 550,
#  'công_sở': 551,
#  'cực_đẹp': 552,
#  'dòng': 553,
#  'dễ_chịu': 554,
#  'may_cotton': 555,
#  'mâc_chất': 556,
#  'mùi': 557,
#  'mặc_gym': 558,
#  'mặc_thường_ngày': 559,
#  'nam_chất': 560,
#  'nam_nữ': 561,
#  'nhuộm': 562,
#  'nhẹ': 563,
#  'nóng_bức': 564,
#  'quần_áo': 565,
#  'sở_thích': 566,
#  'tanktop_nam_nữ': 567,
#  'thể': 568,
#  'thời_áo': 569,
#  'xưởng': 570,
#  'áo_tanktop': 571,
#  'đẹp': 572,
#  'đồ': 573,
#  'cho_bạn': 574,
#  'chân': 575,
#  'công_dụng': 576,
#  'cận': 577,
#  'dã_ngoại': 578,
#  'dạo': 579,
#  'freesize': 580,
#  'học': 581,
#  'lớp': 582,
#  'no_brand': 583,
#  'phù_hợp_mặc': 584,
#  'store_bigsize': 585,
#  'sói': 586,
#  'tc': 587,
#  'tc_mềm': 588,
#  'tập_thể': 589,
#  'unisex_áo': 590,
#  'up': 591,
#  'video': 592,
#  'xù_lông': 593,
#  'đen': 594,
#  'đôi': 595,
#  'chuẩn_from': 596,
#  'chuẩn_gym': 597,
#  'chốt': 598,
#  'cảm_ơn_anh_chị': 599,
#  'from': 600,
#  'hàng_anh_chị': 601,
#  'l_áo': 602,
#  'mặc_ôm': 603,
#  'như_shop': 604,
#  'nhấn': 605,
#  'sale': 606,
#  'shop_bảng': 607,
#  'shop_trân_thành': 608,
#  'shop_ạ': 609,
#  'size_áo': 610,
#  'sản': 611,
#  'sản_phẩm_anh_chị': 612,
#  'tùy_thể_trạng': 613,
#  'vui_lòng_chát': 614,
#  'xong': 615,
#  'xong_anh_chị': 616,
#  'y': 617,
#  'áo_cơ_bắp': 618,
#  'đăng_ạ_anh_chị': 619,
#  'american_style': 620,
#  'bao_đổi': 621,
#  'biển': 622,
#  'bền_bỉ': 623,
#  'chuyên_may': 624,
#  'chất_mát': 625,
#  'gym_mặc': 626,
#  'hình_ảnh': 627,
#  'iphone': 628,
#  'lổ': 629,
#  'miễn_ship': 630,
#  'mát_mẻ': 631,
#  'mịn_màng': 632,
#  'nhà_đi': 633,
#  'nhập_khẩu': 634,
#  'nóng': 635,
#  'quần': 636,
#  'siêu': 637,
#  'tan': 638,
#  'tanktop_nam': 639,
#  'tem': 640,
#  'thưc': 641,
#  'áo_quần': 642,
#  'điện_thoại': 643,
#  'bền': 644,
#  'cam_xanh_ngọc': 645,
#  'chàng': 646,
#  'cm_size': 647,
#  'cotton_gân': 648,
#  'cotton_tăm': 649,
#  'cổ_vuông': 650,
#  'dày_dặn': 651,
#  'gân_tôn_dáng_thương_hiệu': 652,
#  'huỳnh_tấn_phát': 653,
#  'khéo_léo': 654,
#  'mr': 655,
#  'mr_twins': 656,
#  'nam_cổ_vuông': 657,
#  'p_tân_thuận_tây': 658,
#  'size_size': 659,
#  'thước_m': 660,
#  'tnhh': 661,
#  'trẻ_trung': 662,
#  'twins_áo': 663,
#  'vượt_trội': 664,
#  'xanh_xanh_đen': 665,
#  'xl_xl': 666,
#  'xám_kích': 667,
#  'đặt_hàng_chọn': 668,
#  'đỏ': 669,
#  'đứng': 670,
#  'att_áo': 671,
#  'c_sấy': 672,
#  'chu_kỳ': 673,
#  'chính_sách': 674,
#  'chạm': 675,
#  'công_nghệ': 676,
#  'cắt': 677,
#  'giật_tag': 678,
#  'giặt_máy': 679,
#  'in': 680,
#  'kháng_khuẩn': 681,
#  'khủ': 682,
#  'kèm': 683,
#  'kéo': 684,
#  'làn': 685,
#  'lưu_không_khí': 686,
#  'mác': 687,
#  'mát_dịu': 688,
#  'nam_onoff': 689,
#  'nguyên': 690,
#  'ngắn_giặt': 691,
#  'nhiệt_độ': 692,
#  'nhãn_mác': 693,
#  'nhật_bản': 694,
#  'onoff': 695,
#  'quà': 696,
#  'quần_lót': 697,
#  'thẻ': 698,
#  'trung_bình': 699,
#  'tối_đa': 700,
#  'usa': 701,
#  'vong': 702,
#  'áo_cổ_điển': 703,
#  'áp_dụng': 704,
#  'đính': 705,
#  'ủi': 706,
#  'ứng_dụng': 707,
#  'ba_lỗ_sát': 708,
#  'big_sport': 709,
#  'bs_áo': 710,
#  'bàn_chải': 711,
#  'chà_mạnh': 712,
#  'cứng': 713,
#  'dệt_kim': 714,
#  'giặt_tay': 715,
#  'giặt_ủi': 716,
#  'hồ_chí_minh_áo': 717,
#  'khuyến_mãi': 718,
#  'kim_áo': 719,
#  'li_ti': 720,
#  'ma_sát': 721,
#  'mát_vải': 722,
#  'mỏng': 723,
#  'nam_tập': 724,
#  'phai': 725,
#  'regular': 726,
#  'số_lượng': 727,
#  'sợi': 728,
#  'tập': 729,
#  'tập_gym': 730,
#  'vải_nhẹ': 731,
#  'ao_tanks': 732,
#  'cực': 733,
#  'freeship': 734,
#  'hoàn_tiền': 735,
#  'hàng_như_hình_chụp': 736,
#  'lộn': 737,
#  'màu_sắc_trắng': 738,
#  'mát_lạnh': 739,
#  'máy': 740,
#  'mã_skamclu': 741,
#  'mè': 742,
#  'mặt_trái': 743,
#  'nam_nu': 744,
#  'phú_bình': 745,
#  'shop_clothes': 746,
#  'size_oversize': 747,
#  'tanktop_trơn': 748,
#  'thái_nguyên': 749,
#  'thái_thông': 750,
#  'top': 751,
#  'unisex_chuẩn': 752,
#  'đen_basic': 753,
#  'điềm_thụy': 754,
#  'đâu_tiên': 755,
#  'cac': 756,
#  'cang': 757,
#  'cham': 758,
#  'cho_thể': 759,
#  'chuot_gian': 760,
#  'chuyen': 761,
#  'chuyên_dụng': 762,
#  'chạy': 763,
#  'co_qua': 764,
#  'co_đuoc': 765,
#  'devops_form': 766,
#  'dut': 767,
#  'dạng': 768,
#  'giam': 769,
#  'giữ_dáng': 770,
#  'gym_fitness': 771,
#  'hồi': 772,
#  'lưới': 773,
#  'mau_quan_bo': 774,
#  'muc_voi': 775,
#  'môn': 776,
#  'nghiep': 777,
#  'ngoài_trời': 778,
#  'nhãn': 779,
#  'out': 780,
#  'phục_hồi': 781,
#  'poly': 782,
#  'tsla': 783,
#  'tuyệt_đối': 784,
#  'tập_luyện': 785,
#  'tập_tạ': 786,
#  'van': 787,
#  'vien': 788,
#  'work': 789,
#  'đau': 790,
#  'đong': 791,
#  'đàn': 792,
#  'đạp': 793,
#  'ủ': 794,
#  '<': 795,
#  ']': 796,
#  'big': 797,
#  'bigsize': 798,
#  'béo': 799,
#  'chat': 800,
#  'loai': 801,
#  'lạnh_áo': 802,
#  'size_shop': 803,
#  'bình_dương': 804,
#  'chuyên': 805,
#  'chào': 806,
#  'chúc': 807,
#  'cong': 808,
#  'cập_nhật': 809,
#  'duoi': 810,
#  'full': 811,
#  'gap': 812,
#  'ib': 813,
#  'lô': 814,
#  'lôhẹ_nhàng': 815,
#  'mấy': 816,
#  'nhầu': 817,
#  'phân_loại': 818,
#  'quần_soóc': 819,
#  'sai': 820,
#  'shop_nha': 821,
#  'sỉ': 822,
#  'theo_dõi': 823,
#  'thành': 824,
#  'thế_này': 825,
#  'thị_xã': 826,
#  'tân_uyên': 827,
#  'vui_vẻ': 828,
#  'xxxl': 829,
#  'đo': 830,
#  'đu_mau': 831,
#  'đồ_nam': 832,
#  'ủng_hộ': 833,
#  'baokhoa_official_shop': 834,
#  'baokhoa_shop': 835,
#  'chi': 836,
#  'cốt_lõi': 837,
#  'hãng': 838,
#  'xl_áo': 839,
#  'bujnng': 840,
#  'bung': 841,
#  'cảnh_báo': 842,
#  'kỹ_thuật': 843,
#  'lê_đa': 844,
#  'mỹ_trọng': 845,
#  'nam_định': 846,
#  'nặng_size': 847,
#  'phơi': 848,
#  'rửa': 849,
#  'sấy': 850,
#  'sửa_dụng': 851,
#  'thông_số': 852,
#  'trái': 853,
#  'đ': 854,
#  'đồ_tẩy': 855,
#  'ablol_áo': 856,
#  'boutique': 857,
#  'boutique_địa_chỉ': 858,
#  'chiến_lược': 859,
#  'lĩnh_vực': 860,
#  'mã_sản_phẩm': 861,
#  'nghiên_cứu': 862,
#  'nhắn_tin': 863,
#  'phát_triển': 864,
#  'phân_phối': 865,
#  'ra_đời': 866,
#  's_ablol': 867,
#  'sáng_tạo': 868,
#  'tank': 869,
#  'tiên_phong': 870,
#  'trắng_m': 871,
#  'tầm': 872,
#  'tầm_vóc': 873,
#  'đàn_ông': 874,
#  'alhp_áo': 875,
#  'chiều_chuộng': 876,
#  'chuyển_động': 877,
#  'crease_lock': 878,
#  'hạn_chế': 879,
#  'kích_cỡ': 880,
#  'nhu_cầu': 881,
#  'phẳng_phiu': 882,
#  'thể_thao_tsimple': 883,
#  'thể_trạng': 884,
#  'tsimple': 885,
#  'tsimple_chất': 886,
#  'tsimple_sát': 887,
#  'tsimple_áo': 888,
#  'tương_đối': 889,
#  'tập_yoga': 890,
#  'xám': 891,
#  'đà_nẵng': 892,
#  '!_chất': 893,
#  'bai_dãn': 894,
#  'bai_nhão': 895,
#  'gò_bó': 896,
#  'hot': 897,
#  'hôm_nay': 898,
#  'khô_thoáng': 899,
#  'khủng': 900,
#  'mặc_như_không': 901,
#  'mặc_thoáng': 902,
#  'sổ_lông': 903,
#  'vải_sợi': 904,
#  'đông_áo': 905,
#  'ưa_chuộng': 906,
#  'ưu_đãi': 907,
#  'ấm': 908,
#  'anh_chị': 909,
#  'benty': 910,
#  'bụng_bia': 911,
#  'cám_ơn': 912,
#  'da_xanh': 913,
#  'gym_nam': 914,
#  'gymshark': 915,
#  'hình_chụp': 916,
#  'mua_lẻ': 917,
#  'quý': 918,
#  'shop_nhé': 919,
#  'siêu_hot': 920,
#  'sport_áo': 921,
#  'thiên_thanh_đỏ': 922,
#  'trắng_xanh': 923,
#  'tăng_size': 924,
#  'tươi_đỏ_đô': 925,
#  'tỏa': 926,
#  'xác_nhận': 927,
#  '|_ur': 928,
#  'đậm_xanh': 929,
#  'aobalonam': 930,
#  'aobalonamthethao': 931,
#  'aothunbalo': 932,
#  'aothunnamgiare': 933,
#  'aothunnamthethao': 934,
#  'aothunthethao': 935,
#  'chiều-không': 936,
#  'cổ': 937,
#  'cổ-đuôi': 938,
#  'giãn': 939,
#  'giãn-không': 940,
#  'gợi_ý': 941,
#  'khách_hàng_không': 942,
#  'lông': 943,
#  'lạnh-co': 944,
#  'ms': 945,
#  'nặng_shop': 946,
#  'phát_sinh': 947,
#  'phương_châm': 948,
#  'quy_đổi_kích_cỡ': 949,
#  'shop_chịu': 950,
#  'thao-trẻ': 951,
#  'thiết_kế_thể': 952,
#  'thể_thao_chất': 953,
#  'thời_trang_nam': 954,
#  'trung-phù_hợp': 955,
#  'uy_tín': 956,
#  'xò': 957,
#  'đuôi': 958,
#  'đối_tượng': 959,
#  'e_ah': 960,
#  'gò_vấp': 961,
#  'khách_sỉ': 962,
#  'nắng': 963,
#  'suy_nghĩ': 964,
#  'sờ_mát': 965,
#  'thọ': 966,
#  'yên_tâm': 967,
#  'đc': 968,
#  'đt': 969,
#  'chục': 970,
#  'form_classic': 971,
#  'k_áo': 972,
#  'lo': 973,
#  'món': 974,
#  'mùa_hè': 975,
#  'nam_aristino': 976,
#  'nóng_nực': 977,
#  'sở_hữu': 978,
#  'tag': 979,
#  'bong': 980,
#  'chuẩn_áo': 981,
#  'chính_phẩm': 982,
#  'dày': 983,
#  'logo': 984,
#  'mềm_mỏng': 985,
#  'mỏng_siêu': 986,
#  'mồ_hôi_tốt': 987,
#  'ngứa': 988,
#  'nhiệt': 989,
#  'náo_ba': 990,
#  'poly_basic': 991,
#  'poly_mềm': 992,
#  'retro': 993,
#  'siêu_thoáng_mát': 994,
#  'sport_thông_tin': 995,
#  'tem_ép': 996,
#  'tróc': 997,
#  'trơn_basic': 998,
#  'vải_poly': 999,
#  ...}

# %%
# Numbers of features (word) in dictionary
feature_cnt = len(dictionary.token2id)

# %%
feature_cnt
# Out:
# 144190

# %%
# Obtain corpus based on dictionary (dense matrix)
# convert text to BoW (Bag of Words)
# doc2bow(text): This method converts a list of words (the text) into a bag-of-words (BoW) representation. In this representation:
# Each unique word in the document is represented by its corresponding integer ID from the dictionary.
# The output is a list of tuples, where each tuple contains the word ID and its frequency in the document. 
# For example, if a document contains the word "apple" twice and "banana" once, the output might look like [(0, 2), (1, 1)], 
# where 0 and 1 are the IDs for "apple" and "banana", respectively.

corpus = [dictionary.doc2bow(text) for text in df['content_processed']]

# %%
corpus[0] # format is <id>, <frequency>
# Out:
# [(0, 1),
#  (1, 1),
#  (2, 1),
#  (3, 1),
#  (4, 1),
#  (5, 3),
#  (6, 1),
#  (7, 1),
#  (8, 1),
#  (9, 1),
#  (10, 1),
#  (11, 10),
#  (12, 1),
#  (13, 1),
#  (14, 1),
#  (15, 1),
#  (16, 1),
#  (17, 2),
#  (18, 1),
#  (19, 1),
#  (20, 1),
#  (21, 1),
#  (22, 4),
#  (23, 1),
#  (24, 1),
#  (25, 4),
#  (26, 2),
#  (27, 1),
#  (28, 1),
#  (29, 1),
#  (30, 1),
#  (31, 1),
#  (32, 4),
#  (33, 4),
#  (34, 1),
#  (35, 1),
#  (36, 1),
#  (37, 1),
#  (38, 1),
#  (39, 7),
#  (40, 1),
#  (41, 6),
#  (42, 1),
#  (43, 1),
#  (44, 2),
#  (45, 1),
#  (46, 1),
#  (47, 1),
#  (48, 1),
#  (49, 1),
#  (50, 1),
#  (51, 1),
#  (52, 1),
#  (53, 1),
#  (54, 1),
#  (55, 1),
#  (56, 1),
#  (57, 1),
#  (58, 1),
#  (59, 1),
#  (60, 5),
#  (61, 1),
#  (62, 1),
#  (63, 1),
#  (64, 2),
#  (65, 1),
#  (66, 1),
#  (67, 2),
#  (68, 1),
#  (69, 1)]

# %%
# Use TF-IDF Model to process corpus, obtaining index
tfidf = models.TfidfModel(corpus)

# %%
# calculate the similarity between the corpus and the index
# similarity_index_mx = similarities.SparseMatrixSimilarity(tfidf[corpus],
#                                             num_features = feature_cnt)

### this use too much memory, often crashs -> try to use LSI instead.

# %%
# to optimize the calculation of similarity, reduce the memory, using LSI (Latent Sematic Indexing)
# another option is using num_best parameter to keep only only top x most similar items for each document to reduce memory usage.

# Create LSI model
lsi_model = models.LsiModel(tfidf[corpus], id2word=dictionary, num_topics=300)  # Reduce dimensions to 300 topics

# Transform corpus to LSI space
lsi_corpus = lsi_model[tfidf[corpus]]

# %%
# Create similarity index in the reduced space
similarity_index = similarities.MatrixSimilarity(lsi_corpus, num_features=300)

# %% [markdown]
# ######## gensim_df = pd.DataFrame(similarity_index)
# * Converting the entire similarity matrix to a DataFrame is problematic because:
# * dataset has 46,828 documents (as shown in cell 17)
# * This creates a 46,828 × 46,828 matrix (over 2 billion elements)
# * Even with optimized storage, this requires gigabytes of memory
#
# instead, do this:
# * Keep the similarity index as is (it's optimized for memory usage)
# * Calculate similarities only when needed for specific products
# * Only retrieve the top N similar items for a given product

# %%
# Don't convert the entire similarity index to a DataFrame
# gensim_df = pd.DataFrame(similarity_index)

# create a function to get recommendations using the similarity index directly
# moved it to utils

# %%
# Import the reload function
from importlib import reload
import utils

# Reload the utils module to get the latest changes
# by this I don't need to restart the kernel everytime I modify the function in Utils
reload(utils)

# Now try your function call again
from utils import get_recommendations_gensim

# %%
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ### Use case 1: user select a product (productid as input)

# %%
# display the product 19656
selected_product = 19656
selected_product_details= df[df['product_id'] == 19656]

# %%
selected_product_details
# Out:
#       product_id  \
# 1156       19656
#
#                                                                                    product_name  \
# 1156  (A393) DỆT KIM ĐÔNG XUÂN ÁO MAY Ô NAM 3 LỖ MÀU TRẮNG/ ĐEN 209-A0393 DÁNG BODY ÔM SLIM FIT
#
#             category sub_category  \
# 1156  Thời Trang Nam     Áo Ba Lỗ
#
#                                                                                                                                                                                                                                                     link  \
# 1156  https://shopee.vn/(A393)-D%E1%BB%86T-KIM-%C4%90%C3%94NG-XU%C3%82N-%C3%81O-MAY-%C3%94-NAM-3-L%E1%BB%96-M%C3%80U-TR%E1%BA%AENG-%C4%90EN-209-A0393-D%C3%81NG-BODY-%C3%94M-SLIM-FIT-i.279296612.2921494470?sp_atk=16e2bad5-832a-41e6-9ffa-49491761aa4f
#
#      image    price  rating  \
# 1156   NaN  72000.0     5.0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      description  \
# 1156     Áo Ba Lỗ Kho hàng 223 Gửi từ Huyện Đông Anh, Hà Nội  **** DÁNG ÔM  HÀNG PHÂN PHỐI TRỰC TIẾP CỦA CÔNG TY DỆT KIM ĐÔNG XUÂN CAM KẾT HÀNG CHÍNH HÃNG CHẤT LIỆU 100%, THOÁNG MÁT VÀ THẤM HÚT MỒ HÔI, KHÔNG NHƯ HÀNG CHỢ PHA NHIỀU NYLON  Mỗi sản phẩm đều được để trong túi riêng, in đầy đủ thông tin Với chất liệu 100% cotton, mặt vải mịn, thoáng khí, co giãn tốt, có khả năng thấm hút nước cao, thoát nước nhanh khô, đem lại cảm giác thoải mái, tự tin cho người sử dụng Quy trình xử lý vải an toàn, không độc hại, không gây kích ứng da, theo tiêu chuẩn Nhật Bản Áo may ô A0393 là 1 sự lựa chọn hoàn hảo cho nam giới.  #aobalonam #aomayonam #aolotnam #aobalonamdetkimdongxuan #aomayonamdetkimdongxuan #aolotnamdetkimdongxuan #aolotnamtrang #aobalonamtrang #aomayonamtrang #aomayonamcotton #aomayonamcotton #aothunnam #aothunnammautrang #aothunnamtrang #aothunnamtrangcoctay #aothunnamtrangngantay
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       description_clean  \
# 1156  Áo Ba Lỗ Kho hàng 223 Gửi từ Huyện Đông Hà Nội DÁNG ÔM HÀNG PHÂN PHỐI TRỰC TIẾP CỦA CÔNG TY DỆT KIM ĐÔNG XUÂN CAM KẾT HÀNG CHÍNH HÃNG CHẤT LIỆU THOÁNG MÁT VÀ THẤM HÚT MỒ HÔI, KHÔNG NHƯ HÀNG CHỢ PHA NHIỀU NYLON Mỗi sản phẩm đều được để trong túi riêng, in đầy đủ thông tin Với chất liệu 100 mặt vải mịn, thoáng khí, co giãn tốt, có khả năng thấm hút nước thoát nước nhanh khô, đem lại cảm giác thoải mái, tự tin cho người sử dụng Quy trình xử lý vải an toàn, không độc hại, không gây kích ứng theo tiêu chuẩn Nhật Bản Áo may ô A0393 là 1 sự lựa chọn hoàn hảo cho nam giới. aobalonam aomayonam aolotnam aobalonamdetkimdongxuan aomayonamdetkimdongxuan aolotnamdetkimdongxuan aolotnamtrang aobalonamtrang aomayonamtrang aomayonamcotton aomayonamcotton aothunnam aothunnammautrang aothunnamtrang aothunnamtrangcoctay aothunnamtrangngantay
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Content  \
# 1156  (A393) DỆT KIM ĐÔNG XUÂN ÁO MAY Ô NAM 3 LỖ MÀU TRẮNG/ ĐEN 209-A0393 DÁNG BODY ÔM SLIM FIT Áo Ba Lỗ Kho hàng 223 Gửi từ Huyện Đông Hà Nội DÁNG ÔM HÀNG PHÂN PHỐI TRỰC TIẾP CỦA CÔNG TY DỆT KIM ĐÔNG XUÂN CAM KẾT HÀNG CHÍNH HÃNG CHẤT LIỆU THOÁNG MÁT VÀ THẤM HÚT MỒ HÔI, KHÔNG NHƯ HÀNG CHỢ PHA NHIỀU NYLON Mỗi sản phẩm đều được để trong túi riêng, in đầy đủ thông tin Với chất liệu 100 mặt vải mịn, thoáng khí, co giãn tốt, có khả năng thấm hút nước thoát nước nhanh khô, đem lại cảm giác thoải mái, tự tin cho người sử dụng Quy trình xử lý vải an toàn, không độc hại, không gây kích ứng theo tiêu chuẩn Nhật Bản Áo may ô A0393 là 1 sự lựa chọn hoàn hảo cho nam giới. aobalonam aomayonam aolotnam aobalonamdetkimdongxuan aomayonamdetkimdongxuan aolotnamdetkimdongxuan aolotnamtrang aobalonamtrang aomayonamtrang aomayonamcotton aomayonamcotton aothunnam aothunnammautrang aothunnamtrang aothunnamtrangcoctay aothunnamtrangngantay
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Content_wt  \
# 1156  ( A393 ) DỆT_KIM_ĐÔNG XUÂN_ÁO MAY_Ô_NAM 3 LỖ MÀU TRẮNG / ĐEN 209 - A0393_DÁNG BODY_ÔM SLIM FIT_Áo Ba_Lỗ Kho hàng 223 Gửi Huyện_Đông Hà_Nội DÁNG_ÔM HÀNG_PHÂN_PHỐI TRỰC_TIẾP CỦA CÔNG_TY DỆT_KIM_ĐÔNG XUÂN_CAM_KẾT HÀNG_CHÍNH HÃNG CHẤT_LIỆU THOÁNG_MÁT VÀ THẤM_HÚT MỒ_HÔI , KHÔNG NHƯ_HÀNG_CHỢ PHA_NHIỀU NYLON Mỗi sản_phẩm túi , in đầy_đủ thông_tin Với chất_liệu 100 mặt vải mịn , thoáng_khí , co_giãn tốt , khả_năng thấm_hút thoát khô , đem cảm_giác thoải_mái , tự_tin Quy_trình vải an_toàn , không độc_hại , không kích_ứng tiêu_chuẩn Nhật_Bản Áo may_ô A0393 1 lựa_chọn hoàn_hảo nam_giới . aobalonam aomayonam aolotnam aobalonamdetkimdongxuan aomayonamdetkimdongxuan aolotnamdetkimdongxuan aolotnamtrang aobalonamtrang aomayonamtrang aomayonamcotton aomayonamcotton aothunnam aothunnammautrang aothunnamtrang aothunnamtrangcoctay aothunnamtrangngantay
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        content_processed
# 1156  [a, dệt_kim_đông, xuân_áo, may_ô_nam, lỗ, màu, trắng, đen, a_dáng, body_ôm, slim, fit_áo, ba_lỗ, kho, hàng, gửi, huyện_đông, hà_nội, dáng_ôm, hàng_phân_phối, công_ty, dệt_kim_đông, xuân_cam_kết, hàng_chính, hãng, chất_liệu, thoáng_mát, thấm_hút, mồ_hôi, không, như_hàng_chợ, pha_nhiều, nylon, sản_phẩm, túi, in, đầy_đủ, thông_tin, chất_liệu, mặt, vải, mịn, thoáng_khí, co_giãn, tốt, khả_năng, thấm_hút, thoát, khô, đem, cảm_giác, thoải_mái, tự_tin, quy_trình, vải, an_toàn, không, độc_hại, không, kích_ứng, tiêu_chuẩn, nhật_bản, áo, may_ô, a, lựa_chọn, hoàn_hảo, nam_giới, aobalonam, aomayonam, aolotnam, aobalonamdetkimdongxuan, aomayonamdetkimdongxuan, aolotnamdetkimdongxuan, aolotnamtrang, aobalonamtrang, aomayonamtrang, aomayonamcotton, aomayonamcotton, aothunnam, aothunnammautrang, aothunnamtrang, aothunnamtrangcoctay, aothunnamtrangngantay]

# %%
# example, use view product_id = 19656
gensim_prod_recom = get_recommendations_gensim(similarity_index=similarity_index,df=df,tfidf=tfidf,lsi_model=lsi_model,dictionary=dictionary,product_id=selected_product,nums=10)

# %%
gensim_prod_recom
# Out:
#       product_id  \
# 2192       20692
# 1177       19677
# 93          1993
# 36          1936
# 804        19304
# 3            193
# 661       191461
# 810        19310
# 824        19324
# 1323       19823
#
#                                                                                                            product_name  \
# 2192                                                                               Áo may ô Dệt Kim Đông Xuân 154 A0396
# 1177                                            Áo ba lỗ cotton nam hàng xuất khẩu, áo ba lỗ mặc nhà màu trắng hàng đẹp
# 93                                                         Áo Ba lỗ nam 100% coton - hãng Ledatex (Màu xám) có big size
# 36                                            Áo Ba Lỗ Nam Màu Trắng⭐⭐ JUVENO⭐⭐, co giãn 4 chiều, đủ size M-XXL - RSC01
# 804   Áo ba lỗ, áo ba lỗ nam cao cấp - Hàng Việt nam chất lượng cao 100% cotton, mặc mát vào mùa hè, ấm vào mùa đông ..
# 3                                                                                    ÁO BA LỖ HÀNG VIỆT NAM 100% COTTON
# 661                                                                                  ÁO BA LỖ HÀNG VIỆT NAM 100% COTTON
# 810                                                                                       Áo Ba Lỗ Nam Thoáng Mát ABL01
# 824                                                                                     Áo ba lỗ cotton nam hàng loại 2
# 1323                                                                Áo Ba Lỗ YODY Áo Lót Nam Vải Cotton Cao Cấp BLM3001
#
#                    sub_category  rating  similarity_score
# 2192  Áo Hoodie, Áo Len & Áo Nỉ     5.0          0.750625
# 1177                   Áo Ba Lỗ     5.0          0.700594
# 93                     Áo Ba Lỗ     4.9          0.676790
# 36                     Áo Ba Lỗ     5.0          0.655181
# 804                    Áo Ba Lỗ     5.0          0.590434
# 3                      Áo Ba Lỗ     4.8          0.590108
# 661                    Áo Ba Lỗ     0.0          0.588449
# 810                    Áo Ba Lỗ     4.4          0.572474
# 824                    Áo Ba Lỗ     4.7          0.569431
# 1323                   Áo Ba Lỗ     5.0          0.557504

# %% [markdown]
# ### Use case 2: user search for using some keywords (text input)

# %%
### Use case 2: user search using keywords, sentence
queryString = "Áo ba lỗ cotton nam"
gensim_recommendations_by_query = get_recommendations_gensim(similarity_index=similarity_index,df=df,tfidf=tfidf,lsi_model=lsi_model,dictionary=dictionary,query=queryString,nums=10,stop_words=stop_words)

# %%
gensim_recommendations_by_query
# Out:
#       product_id  \
# 419       191219
# 612       191412
# 705        19205
# 1091       19591
# 557       191357
# 509       191309
# 561       191361
# 559       191359
# 465       191265
# 532       191332
#
#                                                                                                                   product_name  \
# 419                                                                                                       Áo ba lỗ nam TTT2222
# 612                     (Giá Sỉ) [Áo 3 lỗ cotton thời trang] Áo ba lỗ và tanktop, Áo ba lỗ vnxk [Áo ba lỗ in họa tiết cao cấp]
# 705     Áo ba lỗ nam sát nách form rộng vải thun cotton mềm mịn thoáng mát unisex big size BIBINO68 Áo tank top nam nữ cao cấp
# 1091                                                                                       Combo 3 Áo ba lỗ nam áo cộc tay nam
# 557                 (Giá Sỉ) [Áo 3 lỗ cotton thời trang] Áo ba lỗ phom rộng, Áo ba lỗ hàng hiệu [Áo ba lỗ in họa tiết cao cấp]
# 509                  (Giá Sỉ) [Áo 3 lỗ cotton thời trang] Áo ba lỗ mùa hè, Áo ba lỗ nam cổ tròn [Áo ba lỗ in họa tiết cao cấp]
# 561                 (Giá Sỉ) [Áo 3 lỗ cotton thời trang] Áo ba lỗ mùa hè, Áo ba lỗ nam thể thao [Áo ba lỗ in họa tiết cao cấp]
# 559                                                           [Chuyên Sỉ Áo Thun] Áo ba lỗ sát nách nam, Áo ba lỗ nam phối màu
# 465                                                                                            Áo ba lỗ đen họa tiết năng động
# 532   Xưởng May Chuyên Sỉ ✨ [Áo 3 lỗ cotton thời trang] Áo thun ba lỗ nam giá rẻ, Áo ba lỗ vnxk [Áo ba lỗ in họa tiết cao cấp]
#
#      sub_category  rating  similarity_score
# 419      Áo Ba Lỗ     0.0          0.883626
# 612      Áo Ba Lỗ     0.0          0.844249
# 705      Áo Ba Lỗ     4.7          0.844222
# 1091     Áo Ba Lỗ     5.0          0.837023
# 557      Áo Ba Lỗ     0.0          0.836305
# 509      Áo Ba Lỗ     0.0          0.836187
# 561      Áo Ba Lỗ     0.0          0.834444
# 559      Áo Ba Lỗ     0.0          0.829950
# 465      Áo Ba Lỗ     5.0          0.827171
# 532      Áo Ba Lỗ     0.0          0.824486

# %% [markdown]
# ### Using Cosine

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Vector hóa nội dung
vectorizer = TfidfVectorizer(analyzer='word', stop_words=stop_words)
tfidf_matrix = vectorizer.fit_transform(df['Content_wt'])

# %%
# # Tính toán độ tương đồng
# cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

# %%
# df_show = pd.DataFrame(cosine_sim)
# df_show

# this will crash the machine as the dataframe is huge.

# %%
reload(utils)
from utils import get_recommendations_cosine

# %%
cosine_recommendations_by_query = get_recommendations_cosine(tfidf_matrix=tfidf_matrix, df=df,product_id=selected_product,nums=10,vectorizer=vectorizer)

# %%
cosine_recommendations_by_query
# Out:
#       product_id  \
# 1265       19765
# 618       191418
# 158        19158
# 926        19426
# 1311       19811
# 1193       19693
# 646       191446
# 529       191329
# 513       191313
# 643       191443
#
#                                                                                                                   product_name  \
# 1265                                                               Áo Ba Lỗ Nam Thể Thao Hyun Boutique - WH01C - Hyun Boutique
# 618                                                COMBO - 4 áo thun nam - 1 vớ Hyun Boutique - Áo ba lỗ nam Cotton thoáng mát
# 158                                                                   Áo Ba Lỗ Tank Top Mau Khô Không Đường May - 2137-KHOTONG
# 926                                                                      Áo Ba Lỗ Tank Top Mau Khô Không Đường May, không nhăn
# 1311                                                                     Áo Ba Lỗ Tank Top Mau Khô Không Đường May 2137 shop88
# 1193                                                            Áo Ba Lỗ Tank Top Mau Khô Không Đường May - 2137_Miễn Phí Ship
# 646                               [Áo 3 lỗ cotton thời trang] Áo ba lỗ nam nữ, Áo ba lỗ cho nam [Áo ba lỗ in họa tiết cao cấp]
# 529    (Giá Tại Kho) [Áo 3 lỗ nam đẹp] Áo thun 3 lỗ nam body, Áo thun 3 lỗ nam nách rộng [Áo ba lỗ thể thao in hình chất lượng
# 513   Thời Trang Cao Cấp Giá Sỉ ✨ [Áo 3 lỗ nam đẹp] Áo ba lỗ mùa hè cho nam, Áo ba lỗ nam tập gym [Áo ba lỗ thể thao in hình c
# 643                           [Áo 3 lỗ cotton thời trang] Áo ba lỗ hàng hiệu, Áo ba lỗ body nam [Áo ba lỗ in họa tiết cao cấp]
#
#      sub_category  rating  similarity_score
# 1265     Áo Ba Lỗ     5.0          0.692265
# 618      Áo Ba Lỗ     0.0          0.573018
# 158      Áo Ba Lỗ     4.7          0.247861
# 926      Áo Ba Lỗ     4.0          0.247479
# 1311     Áo Ba Lỗ     5.0          0.246448
# 1193     Áo Ba Lỗ     5.0          0.244475
# 646      Áo Ba Lỗ     0.0          0.197422
# 529      Áo Ba Lỗ     0.0          0.192640
# 513      Áo Ba Lỗ     0.0          0.192062
# 643      Áo Ba Lỗ     0.0          0.190547

# %%
example_query_recom = "Áo ba lỗ cotton nam"
cosine_query_recom = get_recommendations_cosine(tfidf_matrix=tfidf_matrix, df=df,query=example_query_recom,nums=10,vectorizer=vectorizer)

# %%
cosine_query_recom
# Out:
#      product_id  \
# 561      191361
# 509      191309
# 532      191332
# 612      191412
# 557      191357
# 533      191333
# 562      191362
# 646      191446
# 534      191334
# 611      191411
#
#                                                                                                                  product_name  \
# 561                (Giá Sỉ) [Áo 3 lỗ cotton thời trang] Áo ba lỗ mùa hè, Áo ba lỗ nam thể thao [Áo ba lỗ in họa tiết cao cấp]
# 509                 (Giá Sỉ) [Áo 3 lỗ cotton thời trang] Áo ba lỗ mùa hè, Áo ba lỗ nam cổ tròn [Áo ba lỗ in họa tiết cao cấp]
# 532  Xưởng May Chuyên Sỉ ✨ [Áo 3 lỗ cotton thời trang] Áo thun ba lỗ nam giá rẻ, Áo ba lỗ vnxk [Áo ba lỗ in họa tiết cao cấp]
# 612                    (Giá Sỉ) [Áo 3 lỗ cotton thời trang] Áo ba lỗ và tanktop, Áo ba lỗ vnxk [Áo ba lỗ in họa tiết cao cấp]
# 557                (Giá Sỉ) [Áo 3 lỗ cotton thời trang] Áo ba lỗ phom rộng, Áo ba lỗ hàng hiệu [Áo ba lỗ in họa tiết cao cấp]
# 533  Xưởng May Chuyên Sỉ ✨ [Áo 3 lỗ cotton thời trang] Áo 3 lỗ in hình siêu nét, Áo 3 lỗ nam 3d chất vải mềm mịn [Áo ba lỗ in
# 562                                                   [Chuyên Sỉ Áo Thun] Áo ba lỗ in họa tiết siêu đẹp, Áo ba lỗ nam cổ tròn
# 646                              [Áo 3 lỗ cotton thời trang] Áo ba lỗ nam nữ, Áo ba lỗ cho nam [Áo ba lỗ in họa tiết cao cấp]
# 534        Xưởng May Chuyên Sỉ ✨ [Áo 3 lỗ cotton thời trang] Áo thun ba lỗ, Áo ba lỗ thun lạnh [Áo ba lỗ in họa tiết cao cấp]
# 611  ➡️ [Áo 3 lỗ cotton thời trang] Áo thun ba lỗ kiểu nam, Áo thun ba lỗ nam giá sỉ [Áo ba lỗ in họa tiết cao cấp] [Siêu Đẹp
#
#     sub_category  rating  similarity_score
# 561     Áo Ba Lỗ     0.0          0.677885
# 509     Áo Ba Lỗ     0.0          0.674268
# 532     Áo Ba Lỗ     0.0          0.665093
# 612     Áo Ba Lỗ     0.0          0.650462
# 557     Áo Ba Lỗ     0.0          0.639389
# 533     Áo Ba Lỗ     0.0          0.637576
# 562     Áo Ba Lỗ     0.0          0.636339
# 646     Áo Ba Lỗ     0.0          0.633394
# 534     Áo Ba Lỗ     0.0          0.633246
# 611     Áo Ba Lỗ     0.0          0.628105

# %%
# saving models for Streamlit.
# save Gensime
import pickle
import os

# Create directories if they don't exist
os.makedirs('models', exist_ok=True)
os.makedirs('data', exist_ok=True)

# Save LSI model
with open('models/lsi_model.pkl', 'wb') as f:
    pickle.dump(lsi_model, f)

# Save TF-IDF model
with open('models/tfidf_model.pkl', 'wb') as f:
    pickle.dump(tfidf, f)

# Save dictionary
with open('models/dictionary.pkl', 'wb') as f:
    pickle.dump(dictionary, f)

# Save similarity index
with open('models/similarity_index.pkl', 'wb') as f:
    pickle.dump(similarity_index, f)

# Save processed data
content_processed = df['content_processed'].tolist()  # List of tokenized words
Content_wt = df['Content_wt'].tolist()  # List of processed text strings

# Then save them along with your DataFrame
with open('data/processed_data.pkl', 'wb') as f:
    pickle.dump({
        'df': df,
        'content_processed': content_processed,
        'Content_wt': Content_wt
    }, f)
